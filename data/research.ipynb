# %%
import nasdaqdatalink as quandl
import matplotlib.pyplot as plt
from common import date_util
from data import investment_universe, sharadar_fundamentals, sharadar_prices

# %%
quandl.ApiConfig.api_key = 'NRvcyMwNMXZ2ooDSM3nw'

# %%
universe_size = []
coverage_size = []
prices_size = []
for i in range(1999, 2020):
    for j in range(1, 13):
        end_date = date_util.get_bus_month_end(i, j)
        universe = investment_universe.get_SPX(end_date)
        fundamentals = sharadar_fundamentals.get_fundamentals(universe['ticker'].to_list(), end_date)
        prices = sharadar_prices.get_prices(universe['ticker'].to_list(), end_date)
        
        universe_size.append(universe.shape[0])
        coverage_size.append(fundamentals.shape[0])
        prices_size.append(prices.shape[0])

# %%
plt.plot(universe_size)
plt.plot(coverage_size)
plt.plot(prices_size)
plt.grid()
